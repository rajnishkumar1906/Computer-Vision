# %% [markdown]
# ### Thresholding

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# simple thresholding

# %%
image = cv2.imread("../Images/handwritten.png",cv2.IMREAD_GRAYSCALE)

plt.imshow(image,cmap='grey')

# %%
retrval , binary = cv2.threshold(image,150,255,cv2.THRESH_BINARY)

plt.figure(figsize=(12,7))

plt.imshow(binary,cmap='grey')
plt.show()

# %% [markdown]
# ### Adaptive thresholding

# %%
adaptive_m = cv2.adaptiveThreshold(image, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 11, 15)  #11 is block size

adaptive_g = cv2.adaptiveThreshold(image,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C , cv2.THRESH_BINARY,11,15)

plt.figure(figsize=(12,7))

plt.imshow(adaptive_m,cmap='grey')
plt.title('Adaptive mean thresholding')
plt.show()

plt.imshow(adaptive_g,cmap='grey')
plt.title('Adaptive gaussian thresholding')
plt.show()

# %% [markdown]
# ### Kmeans clustering

# %%
image = cv2.imread("../Images/shapes.png")
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
pixel_values = image.reshape((-1,3))
pixel_values = np.float32(pixel_values)
print(pixel_values)
# Out:
# [[255. 255. 255.]
#  [255. 255. 255.]
#  [255. 255. 255.]
#  ...
#  [255. 255. 255.]
#  [255. 255. 255.]
#  [254. 255. 255.]]

# %%
# criteria defiens stopping condition 
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER ,100 , 0.2)
k = 3
                            #placeholder
_, labels , centers = cv2.kmeans(pixel_values , k , None ,criteria , 10,cv2.KMEANS_RANDOM_CENTERS)

# %%
print(labels.shape)
print(centers)
# Out:
# (1048576, 1)
# [[243.61684  104.52857   63.367916]
#  [255.79164  255.74077  255.77364 ]
#  [ 72.93852  112.9792   169.12305 ]]
