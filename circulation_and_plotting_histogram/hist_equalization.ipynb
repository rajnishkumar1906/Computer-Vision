# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread("../Images/giraffe.png")
if image is None:
    print(f"Image doesn't exist")
else:
    print(f"Image loaded successfully.")
# Out:
# Image loaded successfully.

# %%
image_rgb =  cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
image_gray = cv2.cvtColor(image_rgb,cv2.COLOR_BGR2GRAY)

# %%
hist , bin = np.histogram(image_gray.flatten(),256,[0,256])

# Perform histogram equalization
equalised_image = cv2.equalizeHist(image_gray)

equalised_hist , bins = np.histogram(equalised_image.flatten(),256,[0,256])

# Plot the results
plt.figure(figsize=(12,6))

plt.subplot(2,2,1)
plt.imshow(image_gray,cmap='gray')
plt.title('Original Image')

plt.subplot(2,2,2)
plt.plot(hist,color='blue')
plt.title('Original Image histogram')

plt.subplot(2,2,3)
plt.imshow(equalised_image,cmap='grey')
plt.title('Equalised Image')

plt.subplot(2,2,4)
plt.plot(equalised_hist,color='green')
plt.title('Equalised Image histogram')

plt.tight_layout()
plt.show()
print("'''Histogram Equalizer makes brighter part \n  dark and darker part bright with balanced intensity'''")
# Out:
# '''Histogram Equalizer makes brighter part
#   dark and darker part bright with balanced intensity'''

# %%
"""
Histogram equalization can be dont in only gray space but spme steps has been to take in order to solve multicolor 
LAB channel : L-lightness and A,B carries colro information
Y U V       : Y handles luminance(brightness) U handles blue component and V channel handle red component
              It's dominantly used in media industry (Tv)
"""
# Out:
# "\nHistogram equalization can be dont in only gray space but spme steps has been to take in order to solve multicolor \nLAB channel : L-lightness and A,B carries colro information\nY U V       : Y handles luminance(brightness) U handles blue component and V channel handle red component\n              It's dominantly used in media industry (Tv)\n"

# %%
image_yuv = cv2.cvtColor(image,cv2.COLOR_BGR2YUV)

image_yuv[:,:,0] = cv2.equalizeHist(image_yuv[:,:,0])

equalised_color_image = cv2.cvtColor(image_yuv,cv2.COLOR_YUV2BGR)

equalised_color_image_rgb = cv2.cvtColor(equalised_color_image,cv2.COLOR_BGR2RGB)

# Plot the results
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.imshow(image_rgb,cmap='gray')
plt.title('Original Image')

plt.subplot(1,2,2)
plt.imshow(equalised_color_image_rgb)
plt.title('Equalised RGB Image')

plt.tight_layout()
plt.show()
